# %%
# Out:
# Interface: {'name': 'VPN - VPN Client', 'index': 8, 'description': 'VPN Client Adapter - VPN', 'guid': '{39DA72AF-677E-4130-B77C-0CE69E12E598}', 'mac': '5e:3f:32:c1:dd:96', 'ipv4_metric': 1, 'ipv6_metric': 0, 'ips': ['169.254.248.80']}
#
# Interface: {'name': 'Ethernet', 'index': 13, 'description': 'Realtek PCIe GbE Family Controller', 'guid': '{5746265B-E066-485F-9970-4ED199919933}', 'mac': '04:d4:c4:e8:83:fc', 'ipv4_metric': 5, 'ipv6_metric': 0, 'ips': ['169.254.179.215']}
#
# Interface: {'name': 'ProtonVPN TUN', 'index': 20, 'description': 'ProtonVPN Tunnel', 'guid': '{AFDEECBA-DFBA-CAFF-5044-013412BCEACD}', 'mac': '', 'ipv4_metric': 5, 'ipv6_metric': 5, 'ips': ['fe80::1df:320d:c420:9b60', '169.254.160.23']}
#
# Interface: {'name': 'Local Area Connection', 'index': 15, 'description': 'TAP-Windows Adapter V9', 'guid': '{8D30F333-BB58-4941-9213-9DFA323F9EFE}', 'mac': '00:ff:8d:30:f3:33', 'ipv4_metric': 10, 'ipv6_metric': 0, 'ips': ['169.254.56.51']}
#
# ...
